# %%
while True:
  print("This program is running")
  print("Aww, I was having a good time 😭")
# Out:
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# ...
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# Aww, I was having a good time 😭
# This program is running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bfb7fa7ffea8> in <module>
#       1 while True:
# ----> 2   print("This program is running")
#       3   print("Aww, I was having a good time 😭")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
while True:
  print("You are in a corridor, do you go left or right?")
  direction = input("> ")
  if direction == "left":
    print("You have fallen to your death")
    break
# Out:
# You are in a corridor, do you go left or right?
# > >
# You are in a corridor, do you go left or right?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-161762e74c8e> in <module>
#       1 while True:
#       2   print("You are in a corridor, do you go left or right?")
# ----> 3   direction = input("> ")
#       4   if direction == "left":
#       5     print("You have fallen to your death")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     891             except KeyboardInterrupt:
#     892                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 893                 raise KeyboardInterrupt("Interrupted by user") from None
#     894             else:
#     895                 break
#
# KeyboardInterrupt: Interrupted by user

# %%
while True:
  print("You are in a corridor, do you go left or right?")
  direction = input("> ")
  if direction == "left":
    print("You have fallen to your death")
    break
  elif direction == "right":
    continue
  else:
    print("Ahh! You're a genius, you've won")
# Out:
# You are in a corridor, do you go left or right?
# > right
# You are in a corridor, do you go left or right?
# > >
# Ahh! You're a genius, you've won
# You are in a corridor, do you go left or right?
# > left
# You have fallen to your death

# %%
while True:
  print("You are in a corridor, do you go left or right?")
  direction = input("> ")
  if direction == "left":
    print("You have fallen to your death")
    break
  elif direction == "right":
    continue
  else:
    print("Ahh! You're a genius, you've won")
    break
print("The game is over, you've failed!")
# Out:
# You are in a corridor, do you go left or right?
# > h
# Ahh! You're a genius, you've won
# The game is over, you've failed!

# %%
while True:
  print("You are in a corridor, do you go left or right?")
  direction = input("> ")
  if direction == "left":
    print("You have fallen to your death")
    break
  elif direction == "right":
    continue
  else:
    print("Ahh! You're a genius, you've won")
    exit()
print("The game is over, you've failed!")
# Out:
# You are in a corridor, do you go left or right?
# > m
# Ahh! You're a genius, you've won
# You are in a corridor, do you go left or right?
# > >
# Ahh! You're a genius, you've won
# You are in a corridor, do you go left or right?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d931063fd980> in <module>
#       1 while True:
#       2   print("You are in a corridor, do you go left or right?")
# ----> 3   direction = input("> ")
#       4   if direction == "left":
#       5     print("You have fallen to your death")
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     891             except KeyboardInterrupt:
#     892                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 893                 raise KeyboardInterrupt("Interrupted by user") from None
#     894             else:
#     895                 break
#
# KeyboardInterrupt: Interrupted by user
